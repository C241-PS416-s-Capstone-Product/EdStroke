# %% [markdown]
# ## YouTube Scraper, Video Extractor and MoveNet Processor
#
# This notebook runs the function to infer pose keypoints from YouTube / any video using MoveNet and TensorFlow Lite. The result is a CSV consisting of 17 keypoints * 3 [x, y , score] dimensions 1

# %% [markdown]
# ## Preparation

# %% [markdown]
# In this section, you'll import the necessary libraries and define several functions to scrape the YouTube Video and preprocess the frames

# %%
# !pip install -q opencv-python

# %%
# !pip install pytube@git+https://github.com/priyankaj1311/pytube.git@master_copy
from pytube import YouTube
# Out:
# Collecting pytube@ git+https://github.com/priyankaj1311/pytube.git@master_copy
#   Cloning https://github.com/priyankaj1311/pytube.git (to revision master_copy) to /tmp/pip-install-rtw2fo6b/pytube_9f6eb9f9c6414bceb072cabf2bfac42b
#   Running command git clone --filter=blob:none --quiet https://github.com/priyankaj1311/pytube.git /tmp/pip-install-rtw2fo6b/pytube_9f6eb9f9c6414bceb072cabf2bfac42b
#   Running command git checkout -b master_copy --track origin/master_copy
#   Switched to a new branch 'master_copy'
#   Branch 'master_copy' set up to track remote branch 'master_copy' from 'origin'.
#   Resolved https://github.com/priyankaj1311/pytube.git to commit 68468bd1c0a2d3cd4166d928f4f7f44913c1f77f
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pytube
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=57583 sha256=18b3854c979a533725db6b3cb64b59aaed9fd3d25c454a6b1311f1d3f0c82ece
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pmqdrzpu/wheels/f1/99/7b/8e26a6d0b2f95bcc12bff25ce0952246f2ff57a447560eaf21
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
import csv
import cv2
import itertools
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from IPython.display import Image, display

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ### Code to run pose estimation using MoveNet

# %%
#@title Functions to run pose estimation with MoveNet

#@markdown You'll download the MoveNet Thunder model from [TensorFlow Hub](https://www.google.com/url?sa=D&q=https%3A%2F%2Ftfhub.dev%2Fs%3Fq%3Dmovenet), and reuse some inference and visualization logic from the [MoveNet Raspberry Pi (Python)](https://github.com/tensorflow/examples/tree/master/lite/examples/pose_estimation/raspberry_pi) sample app to detect landmarks (ear, nose, wrist etc.) from the input images.

#@markdown *Note: You should use the most accurate pose estimation model (i.e. MoveNet Thunder) to detect the keypoints and use them to train the pose classification model to achieve the best accuracy. When running inference, you can use a pose estimation model of your choice (e.g. either MoveNet Lightning or Thunder).*

# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# You'll apply MoveNet's cropping algorithm and run inference multiple times on
# the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=3):
  """Runs detection on an input image.

  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.

  Returns:
    A Person entity detected by the MoveNet.SinglePose.
  """
  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23745, done.
# remote: Total 23745 (delta 0), reused 0 (delta 0), pack-reused 23745
# Receiving objects: 100% (23745/23745), 44.08 MiB | 22.53 MiB/s, done.
# Resolving deltas: 100% (12948/12948), done.

# %%
#@title Functions to download YouTube video.
YouTubeVideo = "https://youtu.be/wYzGtkcttVE" #@param {type:"string"}
filename = "woozooDance" #@param {type:"string"}
video_path = "exercise/woozooDance/video" #@param {type:"string"}

def download_youtube_video(url, output_path, filename='filename'):
    # Ensure the output directory exists
    os.makedirs(output_path, exist_ok=True)

    yt = YouTube(url)
    stream = yt.streams.get_highest_resolution()
    file_path = os.path.join(output_path, f"{filename}.mp4")

    if not os.path.exists(file_path):
        stream.download(output_path=output_path, filename=filename)
    else:
        print(f"File '{filename}.mp4' already exists in '{output_path}', skipping download.")
        print(f"Existing file path: {file_path}")

download_youtube_video(YouTubeVideo, video_path, filename)

# %%
#@title Functions to see video properties.

video_path = "exercise/woozooDance/video/woozooDance" #@param {type:"string"}

def get_video_properties(video_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Unable to open video file.")
        return None, None, None, None
    # Get frames per second (fps)
    fps = cap.get(cv2.CAP_PROP_FPS)
    # Get total frame count
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    # Calculate duration in seconds
    duration = total_frames / fps
    # Get video width and height resolution
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    cap.release()
    return duration, total_frames, fps, width, height

duration, total_frames, fps, width, height = get_video_properties(video_path)

if duration is not None and total_frames is not None and fps is not None:
    print(f"Video Duration: {duration:.2f} seconds")
    print(f"Total Frame Count: {total_frames}")
    print(f"Frames Per Second (FPS): {fps:.2f}")
    print(f"Resolution: width is {width} and height is {height}")
# Out:
# Video Duration: 88.10 seconds
# Total Frame Count: 2643
# Frames Per Second (FPS): 30.00
# Resolution: width is 606 and height is 360

# %%
#@title Functions to extract frames.

video_path = "exercise/woozooDance/video/woozooDance" #@param {type:"string"}
start_frame = 0 #@param {type:"integer"}
end_frame = 2600 #@param {type:"integer"}
frame_interval = 2 #@param {type:"integer"}
output_path = "exercise/woozooDance/inputFrames/" #@param {type:"string"}

def extract_frames(video_path, start_frame, end_frame, frame_interval, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Unable to open video file.")
        return

    frame_count = 0
    os.makedirs(output_path, exist_ok=True)

    print("Starting frame extraction process...")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count < start_frame:
            frame_count += 1
            continue
        elif frame_count > end_frame:
            break

        # Process every `frame_interval` frame
        if frame_count % frame_interval == 0:
            print(f"Processing frame {frame_count}")

            # Save the frame directly to the output path
            frame_filename = os.path.join(output_path, f"frame_{frame_count}.jpg")
            cv2.imwrite(frame_filename, frame)
            print(f"Saved frame {frame_count}")

        frame_count += 1

    cap.release()
    print("Frame extraction process completed.")

extract_frames(video_path, start_frame, end_frame, frame_interval, output_path)
# Out:
# Starting frame extraction process...
# Processing frame 0
# Saved frame 0
# Processing frame 2
# Saved frame 2
# Processing frame 4
# Saved frame 4
# Processing frame 6
# Saved frame 6
# Processing frame 8
# Saved frame 8
# Processing frame 10
# Saved frame 10
# Processing frame 12
# Saved frame 12
# Processing frame 14
# Saved frame 14
# Processing frame 16
# Saved frame 16
# Processing frame 18
# Saved frame 18
# Processing frame 20
# Saved frame 20
# Processing frame 22
# Saved frame 22
# Processing frame 24
# Saved frame 24
# Processing frame 26
# Saved frame 26
# Processing frame 28
# Saved frame 28
# Processing frame 30
# Saved frame 30
# Processing frame 32
# Saved frame 32
# Processing frame 34
# Saved frame 34
# Processing frame 36
# Saved frame 36
# Processing frame 38
# Saved frame 38
# Processing frame 40
# Saved frame 40
# Processing frame 42
# Saved frame 42
# Processing frame 44
# Saved frame 44
# Processing frame 46
# Saved frame 46
# Processing frame 48
# Saved frame 48
# Processing frame 50
# Saved frame 50
# Processing frame 52
# Saved frame 52
# Processing frame 54
# Saved frame 54
# Processing frame 56
# Saved frame 56
# Processing frame 58
# Saved frame 58
# Processing frame 60
# Saved frame 60
# Processing frame 62
# Saved frame 62
# Processing frame 64
# Saved frame 64
# Processing frame 66
# Saved frame 66
# Processing frame 68
# Saved frame 68
# Processing frame 70
# Saved frame 70
# Processing frame 72
# Saved frame 72
# Processing frame 74
# Saved frame 74
# Processing frame 76
# Saved frame 76
# Processing frame 78
# Saved frame 78
# Processing frame 80
# Saved frame 80
# Processing frame 82
# Saved frame 82
# Processing frame 84
# Saved frame 84
# Processing frame 86
# Saved frame 86
# Processing frame 88
# Saved frame 88
# Processing frame 90
# Saved frame 90
# Processing frame 92
# Saved frame 92
# Processing frame 94
# Saved frame 94
# Processing frame 96
# Saved frame 96
# Processing frame 98
# Saved frame 98
# Processing frame 100
# Saved frame 100
# Processing frame 102
# Saved frame 102
# Processing frame 104
# Saved frame 104
# Processing frame 106
# Saved frame 106
# Processing frame 108
# Saved frame 108
# Processing frame 110
# Saved frame 110
# Processing frame 112
# Saved frame 112
# Processing frame 114
# Saved frame 114
# Processing frame 116
# Saved frame 116
# Processing frame 118
# Saved frame 118
# Processing frame 120
# Saved frame 120
# Processing frame 122
# Saved frame 122
# Processing frame 124
# Saved frame 124
# Processing frame 126
# Saved frame 126
# Processing frame 128
# Saved frame 128
# Processing frame 130
# Saved frame 130
# Processing frame 132
# Saved frame 132
# Processing frame 134
# Saved frame 134
# Processing frame 136
# Saved frame 136
# Processing frame 138
# Saved frame 138
# Processing frame 140
# Saved frame 140
# Processing frame 142
# Saved frame 142
# Processing frame 144
# Saved frame 144
# Processing frame 146
# Saved frame 146
# Processing frame 148
# Saved frame 148
# Processing frame 150
# Saved frame 150
# Processing frame 152
# Saved frame 152
# Processing frame 154
# Saved frame 154
# Processing frame 156
# Saved frame 156
# Processing frame 158
# Saved frame 158
# Processing frame 160
# Saved frame 160
# Processing frame 162
# Saved frame 162
# Processing frame 164
# Saved frame 164
# Processing frame 166
# Saved frame 166
# Processing frame 168
# Saved frame 168
# Processing frame 170
# Saved frame 170
# Processing frame 172
# Saved frame 172
# Processing frame 174
# Saved frame 174
# Processing frame 176
# Saved frame 176
# Processing frame 178
# Saved frame 178
# Processing frame 180
# Saved frame 180
# Processing frame 182
# Saved frame 182
# Processing frame 184
# Saved frame 184
# Processing frame 186
# Saved frame 186
# Processing frame 188
# Saved frame 188
# Processing frame 190
# Saved frame 190
# Processing frame 192
# Saved frame 192
# Processing frame 194
# Saved frame 194
# Processing frame 196
# Saved frame 196
# Processing frame 198
# Saved frame 198
# Processing frame 200
# Saved frame 200
# Processing frame 202
# Saved frame 202
# Processing frame 204
# Saved frame 204
# Processing frame 206
# Saved frame 206
# Processing frame 208
# Saved frame 208
# Processing frame 210
# Saved frame 210
# Processing frame 212
# Saved frame 212
# Processing frame 214
# Saved frame 214
# Processing frame 216
# Saved frame 216
# Processing frame 218
# Saved frame 218
# Processing frame 220
# Saved frame 220
# Processing frame 222
# Saved frame 222
# Processing frame 224
# Saved frame 224
# Processing frame 226
# Saved frame 226
# Processing frame 228
# Saved frame 228
# Processing frame 230
# Saved frame 230
# Processing frame 232
# Saved frame 232
# Processing frame 234
# Saved frame 234
# Processing frame 236
# Saved frame 236
# Processing frame 238
# Saved frame 238
# Processing frame 240
# Saved frame 240
# Processing frame 242
# Saved frame 242
# Processing frame 244
# Saved frame 244
# Processing frame 246
# Saved frame 246
# Processing frame 248
# Saved frame 248
# Processing frame 250
# Saved frame 250
# Processing frame 252
# Saved frame 252
# Processing frame 254
# Saved frame 254
# Processing frame 256
# Saved frame 256
# Processing frame 258
# Saved frame 258
# Processing frame 260
# Saved frame 260
# Processing frame 262
# Saved frame 262
# Processing frame 264
# Saved frame 264
# Processing frame 266
# Saved frame 266
# Processing frame 268
# Saved frame 268
# Processing frame 270
# Saved frame 270
# Processing frame 272
# Saved frame 272
# Processing frame 274
# Saved frame 274
# Processing frame 276
# Saved frame 276
# Processing frame 278
# Saved frame 278
# Processing frame 280
# Saved frame 280
# Processing frame 282
# Saved frame 282
# Processing frame 284
# Saved frame 284
# Processing frame 286
# Saved frame 286
# Processing frame 288
# Saved frame 288
# Processing frame 290
# Saved frame 290
# Processing frame 292
# Saved frame 292
# Processing frame 294
# Saved frame 294
# Processing frame 296
# Saved frame 296
# Processing frame 298
# Saved frame 298
# Processing frame 300
# Saved frame 300
# Processing frame 302
# Saved frame 302
# Processing frame 304
# Saved frame 304
# Processing frame 306
# Saved frame 306
# Processing frame 308
# Saved frame 308
# Processing frame 310
# Saved frame 310
# Processing frame 312
# Saved frame 312
# Processing frame 314
# Saved frame 314
# Processing frame 316
# Saved frame 316
# Processing frame 318
# Saved frame 318
# Processing frame 320
# Saved frame 320
# Processing frame 322
# Saved frame 322
# Processing frame 324
# Saved frame 324
# Processing frame 326
# Saved frame 326
# Processing frame 328
# Saved frame 328
# Processing frame 330
# Saved frame 330
# Processing frame 332
# Saved frame 332
# Processing frame 334
# Saved frame 334
# Processing frame 336
# Saved frame 336
# Processing frame 338
# Saved frame 338
# Processing frame 340
# Saved frame 340
# Processing frame 342
# Saved frame 342
# Processing frame 344
# Saved frame 344
# Processing frame 346
# Saved frame 346
# Processing frame 348
# Saved frame 348
# Processing frame 350
# Saved frame 350
# Processing frame 352
# Saved frame 352
# Processing frame 354
# Saved frame 354
# Processing frame 356
# Saved frame 356
# Processing frame 358
# Saved frame 358
# Processing frame 360
# Saved frame 360
# Processing frame 362
# Saved frame 362
# Processing frame 364
# Saved frame 364
# Processing frame 366
# Saved frame 366
# Processing frame 368
# Saved frame 368
# Processing frame 370
# Saved frame 370
# Processing frame 372
# Saved frame 372
# Processing frame 374
# Saved frame 374
# Processing frame 376
# Saved frame 376
# Processing frame 378
# Saved frame 378
# Processing frame 380
# Saved frame 380
# Processing frame 382
# Saved frame 382
# Processing frame 384
# Saved frame 384
# Processing frame 386
# Saved frame 386
# Processing frame 388
# Saved frame 388
# Processing frame 390
# Saved frame 390
# Processing frame 392
# Saved frame 392
# Processing frame 394
# Saved frame 394
# Processing frame 396
# Saved frame 396
# Processing frame 398
# Saved frame 398
# Processing frame 400
# Saved frame 400
# Processing frame 402
# Saved frame 402
# Processing frame 404
# Saved frame 404
# Processing frame 406
# Saved frame 406
# Processing frame 408
# Saved frame 408
# Processing frame 410
# Saved frame 410
# Processing frame 412
# Saved frame 412
# Processing frame 414
# Saved frame 414
# Processing frame 416
# Saved frame 416
# Processing frame 418
# Saved frame 418
# Processing frame 420
# Saved frame 420
# Processing frame 422
# Saved frame 422
# Processing frame 424
# Saved frame 424
# Processing frame 426
# Saved frame 426
# Processing frame 428
# Saved frame 428
# Processing frame 430
# Saved frame 430
# Processing frame 432
# Saved frame 432
# Processing frame 434
# Saved frame 434
# Processing frame 436
# Saved frame 436
# Processing frame 438
# Saved frame 438
# Processing frame 440
# Saved frame 440
# Processing frame 442
# Saved frame 442
# Processing frame 444
# Saved frame 444
# Processing frame 446
# Saved frame 446
# Processing frame 448
# Saved frame 448
# Processing frame 450
# Saved frame 450
# Processing frame 452
# Saved frame 452
# Processing frame 454
# Saved frame 454
# Processing frame 456
# Saved frame 456
# Processing frame 458
# Saved frame 458
# Processing frame 460
# Saved frame 460
# Processing frame 462
# Saved frame 462
# Processing frame 464
# Saved frame 464
# Processing frame 466
# Saved frame 466
# Processing frame 468
# Saved frame 468
# Processing frame 470
# Saved frame 470
# Processing frame 472
# Saved frame 472
# Processing frame 474
# Saved frame 474
# Processing frame 476
# Saved frame 476
# Processing frame 478
# Saved frame 478
# Processing frame 480
# Saved frame 480
# Processing frame 482
# Saved frame 482
# Processing frame 484
# Saved frame 484
# Processing frame 486
# Saved frame 486
# Processing frame 488
# Saved frame 488
# Processing frame 490
# Saved frame 490
# Processing frame 492
# Saved frame 492
# Processing frame 494
# Saved frame 494
# Processing frame 496
# Saved frame 496
# Processing frame 498
# Saved frame 498
# Processing frame 500
# Saved frame 500
# Processing frame 502
# Saved frame 502
# Processing frame 504
# Saved frame 504
# Processing frame 506
# Saved frame 506
# Processing frame 508
# Saved frame 508
# Processing frame 510
# Saved frame 510
# Processing frame 512
# Saved frame 512
# Processing frame 514
# Saved frame 514
# Processing frame 516
# Saved frame 516
# Processing frame 518
# Saved frame 518
# Processing frame 520
# Saved frame 520
# Processing frame 522
# Saved frame 522
# Processing frame 524
# Saved frame 524
# Processing frame 526
# Saved frame 526
# Processing frame 528
# Saved frame 528
# Processing frame 530
# Saved frame 530
# Processing frame 532
# Saved frame 532
# Processing frame 534
# Saved frame 534
# Processing frame 536
# Saved frame 536
# Processing frame 538
# Saved frame 538
# Processing frame 540
# Saved frame 540
# Processing frame 542
# Saved frame 542
# Processing frame 544
# Saved frame 544
# Processing frame 546
# Saved frame 546
# Processing frame 548
# Saved frame 548
# Processing frame 550
# Saved frame 550
# Processing frame 552
# Saved frame 552
# Processing frame 554
# Saved frame 554
# Processing frame 556
# Saved frame 556
# Processing frame 558
# Saved frame 558
# Processing frame 560
# Saved frame 560
# Processing frame 562
# Saved frame 562
# Processing frame 564
# Saved frame 564
# Processing frame 566
# Saved frame 566
# Processing frame 568
# Saved frame 568
# Processing frame 570
# Saved frame 570
# Processing frame 572
# Saved frame 572
# Processing frame 574
# Saved frame 574
# Processing frame 576
# Saved frame 576
# Processing frame 578
# Saved frame 578
# Processing frame 580
# Saved frame 580
# Processing frame 582
# Saved frame 582
# Processing frame 584
# Saved frame 584
# Processing frame 586
# Saved frame 586
# Processing frame 588
# Saved frame 588
# Processing frame 590
# Saved frame 590
# Processing frame 592
# Saved frame 592
# Processing frame 594
# Saved frame 594
# Processing frame 596
# Saved frame 596
# Processing frame 598
# Saved frame 598
# Processing frame 600
# Saved frame 600
# Processing frame 602
# Saved frame 602
# Processing frame 604
# Saved frame 604
# Processing frame 606
# Saved frame 606
# Processing frame 608
# Saved frame 608
# Processing frame 610
# Saved frame 610
# Processing frame 612
# Saved frame 612
# Processing frame 614
# Saved frame 614
# Processing frame 616
# Saved frame 616
# Processing frame 618
# Saved frame 618
# Processing frame 620
# Saved frame 620
# Processing frame 622
# Saved frame 622
# Processing frame 624
# Saved frame 624
# Processing frame 626
# Saved frame 626
# Processing frame 628
# Saved frame 628
# Processing frame 630
# Saved frame 630
# Processing frame 632
# Saved frame 632
# Processing frame 634
# Saved frame 634
# Processing frame 636
# Saved frame 636
# Processing frame 638
# Saved frame 638
# Processing frame 640
# Saved frame 640
# Processing frame 642
# Saved frame 642
# Processing frame 644
# Saved frame 644
# Processing frame 646
# Saved frame 646
# Processing frame 648
# Saved frame 648
# Processing frame 650
# Saved frame 650
# Processing frame 652
# Saved frame 652
# Processing frame 654
# Saved frame 654
# Processing frame 656
# Saved frame 656
# Processing frame 658
# Saved frame 658
# Processing frame 660
# Saved frame 660
# Processing frame 662
# Saved frame 662
# Processing frame 664
# Saved frame 664
# Processing frame 666
# Saved frame 666
# Processing frame 668
# Saved frame 668
# Processing frame 670
# Saved frame 670
# Processing frame 672
# Saved frame 672
# Processing frame 674
# Saved frame 674
# Processing frame 676
# Saved frame 676
# Processing frame 678
# Saved frame 678
# Processing frame 680
# Saved frame 680
# Processing frame 682
# Saved frame 682
# Processing frame 684
# Saved frame 684
# Processing frame 686
# Saved frame 686
# Processing frame 688
# Saved frame 688
# Processing frame 690
# Saved frame 690
# Processing frame 692
# Saved frame 692
# Processing frame 694
# Saved frame 694
# Processing frame 696
# Saved frame 696
# Processing frame 698
# Saved frame 698
# Processing frame 700
# Saved frame 700
# Processing frame 702
# Saved frame 702
# Processing frame 704
# Saved frame 704
# Processing frame 706
# Saved frame 706
# Processing frame 708
# Saved frame 708
# Processing frame 710
# Saved frame 710
# Processing frame 712
# Saved frame 712
# Processing frame 714
# Saved frame 714
# Processing frame 716
# Saved frame 716
# Processing frame 718
# Saved frame 718
# Processing frame 720
# Saved frame 720
# Processing frame 722
# Saved frame 722
# Processing frame 724
# Saved frame 724
# Processing frame 726
# Saved frame 726
# Processing frame 728
# Saved frame 728
# Processing frame 730
# Saved frame 730
# Processing frame 732
# Saved frame 732
# Processing frame 734
# Saved frame 734
# Processing frame 736
# Saved frame 736
# Processing frame 738
# Saved frame 738
# Processing frame 740
# Saved frame 740
# Processing frame 742
# Saved frame 742
# Processing frame 744
# Saved frame 744
# Processing frame 746
# Saved frame 746
# Processing frame 748
# Saved frame 748
# Processing frame 750
# Saved frame 750
# Processing frame 752
# Saved frame 752
# Processing frame 754
# Saved frame 754
# Processing frame 756
# Saved frame 756
# Processing frame 758
# Saved frame 758
# Processing frame 760
# Saved frame 760
# Processing frame 762
# Saved frame 762
# Processing frame 764
# Saved frame 764
# Processing frame 766
# Saved frame 766
# Processing frame 768
# Saved frame 768
# Processing frame 770
# Saved frame 770
# Processing frame 772
# Saved frame 772
# Processing frame 774
# Saved frame 774
# Processing frame 776
# Saved frame 776
# Processing frame 778
# Saved frame 778
# Processing frame 780
# Saved frame 780
# Processing frame 782
# Saved frame 782
# Processing frame 784
# Saved frame 784
# Processing frame 786
# Saved frame 786
# Processing frame 788
# Saved frame 788
# Processing frame 790
# Saved frame 790
# Processing frame 792
# Saved frame 792
# Processing frame 794
# Saved frame 794
# Processing frame 796
# Saved frame 796
# Processing frame 798
# Saved frame 798
# Processing frame 800
# Saved frame 800
# Processing frame 802
# Saved frame 802
# Processing frame 804
# Saved frame 804
# Processing frame 806
# Saved frame 806
# Processing frame 808
# Saved frame 808
# Processing frame 810
# Saved frame 810
# Processing frame 812
# Saved frame 812
# Processing frame 814
# Saved frame 814
# Processing frame 816
# Saved frame 816
# Processing frame 818
# Saved frame 818
# Processing frame 820
# Saved frame 820
# Processing frame 822
# Saved frame 822
# Processing frame 824
# Saved frame 824
# Processing frame 826
# Saved frame 826
# Processing frame 828
# Saved frame 828
# Processing frame 830
# Saved frame 830
# Processing frame 832
# Saved frame 832
# Processing frame 834
# Saved frame 834
# Processing frame 836
# Saved frame 836
# Processing frame 838
# Saved frame 838
# Processing frame 840
# Saved frame 840
# Processing frame 842
# Saved frame 842
# Processing frame 844
# Saved frame 844
# Processing frame 846
# Saved frame 846
# Processing frame 848
# Saved frame 848
# Processing frame 850
# Saved frame 850
# Processing frame 852
# Saved frame 852
# Processing frame 854
# Saved frame 854
# Processing frame 856
# Saved frame 856
# Processing frame 858
# Saved frame 858
# Processing frame 860
# Saved frame 860
# Processing frame 862
# Saved frame 862
# Processing frame 864
# Saved frame 864
# Processing frame 866
# Saved frame 866
# Processing frame 868
# Saved frame 868
# Processing frame 870
# Saved frame 870
# Processing frame 872
# Saved frame 872
# Processing frame 874
# Saved frame 874
# Processing frame 876
# Saved frame 876
# Processing frame 878
# Saved frame 878
# Processing frame 880
# Saved frame 880
# Processing frame 882
# Saved frame 882
# Processing frame 884
# Saved frame 884
# Processing frame 886
# Saved frame 886
# Processing frame 888
# Saved frame 888
# Processing frame 890
# Saved frame 890
# Processing frame 892
# Saved frame 892
# Processing frame 894
# Saved frame 894
# Processing frame 896
# Saved frame 896
# Processing frame 898
# Saved frame 898
# Processing frame 900
# Saved frame 900
# Processing frame 902
# Saved frame 902
# Processing frame 904
# Saved frame 904
# Processing frame 906
# Saved frame 906
# Processing frame 908
# Saved frame 908
# Processing frame 910
# Saved frame 910
# Processing frame 912
# Saved frame 912
# Processing frame 914
# Saved frame 914
# Processing frame 916
# Saved frame 916
# Processing frame 918
# Saved frame 918
# Processing frame 920
# Saved frame 920
# Processing frame 922
# Saved frame 922
# Processing frame 924
# Saved frame 924
# Processing frame 926
# Saved frame 926
# Processing frame 928
# Saved frame 928
# Processing frame 930
# Saved frame 930
# Processing frame 932
# Saved frame 932
# Processing frame 934
# Saved frame 934
# Processing frame 936
# Saved frame 936
# Processing frame 938
# Saved frame 938
# Processing frame 940
# Saved frame 940
# Processing frame 942
# Saved frame 942
# Processing frame 944
# Saved frame 944
# Processing frame 946
# Saved frame 946
# Processing frame 948
# Saved frame 948
# Processing frame 950
# Saved frame 950
# Processing frame 952
# Saved frame 952
# Processing frame 954
# Saved frame 954
# Processing frame 956
# Saved frame 956
# Processing frame 958
# Saved frame 958
# Processing frame 960
# Saved frame 960
# Processing frame 962
# Saved frame 962
# Processing frame 964
# Saved frame 964
# Processing frame 966
# Saved frame 966
# Processing frame 968
# Saved frame 968
# Processing frame 970
# Saved frame 970
# Processing frame 972
# Saved frame 972
# Processing frame 974
# Saved frame 974
# Processing frame 976
# Saved frame 976
# Processing frame 978
# Saved frame 978
# Processing frame 980
# Saved frame 980
# Processing frame 982
# Saved frame 982
# Processing frame 984
# Saved frame 984
# Processing frame 986
# Saved frame 986
# Processing frame 988
# Saved frame 988
# Processing frame 990
# Saved frame 990
# Processing frame 992
# Saved frame 992
# Processing frame 994
# Saved frame 994
# Processing frame 996
# Saved frame 996
# Processing frame 998
# Saved frame 998
# Processing frame 1000
# Saved frame 1000
# Processing frame 1002
# Saved frame 1002
# Processing frame 1004
# Saved frame 1004
# Processing frame 1006
# Saved frame 1006
# Processing frame 1008
# Saved frame 1008
# Processing frame 1010
# Saved frame 1010
# Processing frame 1012
# Saved frame 1012
# Processing frame 1014
# Saved frame 1014
# Processing frame 1016
# Saved frame 1016
# Processing frame 1018
# Saved frame 1018
# Processing frame 1020
# Saved frame 1020
# Processing frame 1022
# Saved frame 1022
# Processing frame 1024
# Saved frame 1024
# Processing frame 1026
# Saved frame 1026
# Processing frame 1028
# Saved frame 1028
# Processing frame 1030
# Saved frame 1030
# Processing frame 1032
# Saved frame 1032
# Processing frame 1034
# Saved frame 1034
# Processing frame 1036
# Saved frame 1036
# Processing frame 1038
# Saved frame 1038
# Processing frame 1040
# Saved frame 1040
# Processing frame 1042
# Saved frame 1042
# Processing frame 1044
# Saved frame 1044
# Processing frame 1046
# Saved frame 1046
# Processing frame 1048
# Saved frame 1048
# Processing frame 1050
# Saved frame 1050
# Processing frame 1052
# Saved frame 1052
# Processing frame 1054
# Saved frame 1054
# Processing frame 1056
# Saved frame 1056
# Processing frame 1058
# Saved frame 1058
# Processing frame 1060
# Saved frame 1060
# Processing frame 1062
# Saved frame 1062
# Processing frame 1064
# Saved frame 1064
# Processing frame 1066
# Saved frame 1066
# Processing frame 1068
# Saved frame 1068
# Processing frame 1070
# Saved frame 1070
# Processing frame 1072
# Saved frame 1072
# Processing frame 1074
# Saved frame 1074
# Processing frame 1076
# Saved frame 1076
# Processing frame 1078
# Saved frame 1078
# Processing frame 1080
# Saved frame 1080
# Processing frame 1082
# Saved frame 1082
# Processing frame 1084
# Saved frame 1084
# Processing frame 1086
# Saved frame 1086
# Processing frame 1088
# Saved frame 1088
# Processing frame 1090
# Saved frame 1090
# Processing frame 1092
# Saved frame 1092
# Processing frame 1094
# Saved frame 1094
# Processing frame 1096
# Saved frame 1096
# Processing frame 1098
# Saved frame 1098
# Processing frame 1100
# Saved frame 1100
# Processing frame 1102
# Saved frame 1102
# Processing frame 1104
# Saved frame 1104
# Processing frame 1106
# Saved frame 1106
# Processing frame 1108
# Saved frame 1108
# Processing frame 1110
# Saved frame 1110
# Processing frame 1112
# Saved frame 1112
# Processing frame 1114
# Saved frame 1114
# Processing frame 1116
# Saved frame 1116
# Processing frame 1118
# Saved frame 1118
# Processing frame 1120
# Saved frame 1120
# Processing frame 1122
# Saved frame 1122
# Processing frame 1124
# Saved frame 1124
# Processing frame 1126
# Saved frame 1126
# Processing frame 1128
# Saved frame 1128
# Processing frame 1130
# Saved frame 1130
# Processing frame 1132
# Saved frame 1132
# Processing frame 1134
# Saved frame 1134
# Processing frame 1136
# Saved frame 1136
# Processing frame 1138
# Saved frame 1138
# Processing frame 1140
# Saved frame 1140
# Processing frame 1142
# Saved frame 1142
# Processing frame 1144
# Saved frame 1144
# Processing frame 1146
# Saved frame 1146
# Processing frame 1148
# Saved frame 1148
# Processing frame 1150
# Saved frame 1150
# Processing frame 1152
# Saved frame 1152
# Processing frame 1154
# Saved frame 1154
# Processing frame 1156
# Saved frame 1156
# Processing frame 1158
# Saved frame 1158
# Processing frame 1160
# Saved frame 1160
# Processing frame 1162
# Saved frame 1162
# Processing frame 1164
# Saved frame 1164
# Processing frame 1166
# Saved frame 1166
# Processing frame 1168
# Saved frame 1168
# Processing frame 1170
# Saved frame 1170
# Processing frame 1172
# Saved frame 1172
# Processing frame 1174
# Saved frame 1174
# Processing frame 1176
# Saved frame 1176
# Processing frame 1178
# Saved frame 1178
# Processing frame 1180
# Saved frame 1180
# Processing frame 1182
# Saved frame 1182
# Processing frame 1184
# Saved frame 1184
# Processing frame 1186
# Saved frame 1186
# Processing frame 1188
# Saved frame 1188
# Processing frame 1190
# Saved frame 1190
# Processing frame 1192
# Saved frame 1192
# Processing frame 1194
# Saved frame 1194
# Processing frame 1196
# Saved frame 1196
# Processing frame 1198
# Saved frame 1198
# Processing frame 1200
# Saved frame 1200
# Processing frame 1202
# Saved frame 1202
# Processing frame 1204
# Saved frame 1204
# Processing frame 1206
# Saved frame 1206
# Processing frame 1208
# Saved frame 1208
# Processing frame 1210
# Saved frame 1210
# Processing frame 1212
# Saved frame 1212
# Processing frame 1214
# Saved frame 1214
# Processing frame 1216
# Saved frame 1216
# Processing frame 1218
# Saved frame 1218
# Processing frame 1220
# Saved frame 1220
# Processing frame 1222
# Saved frame 1222
# Processing frame 1224
# Saved frame 1224
# Processing frame 1226
# Saved frame 1226
# Processing frame 1228
# Saved frame 1228
# Processing frame 1230
# Saved frame 1230
# Processing frame 1232
# Saved frame 1232
# Processing frame 1234
# Saved frame 1234
# Processing frame 1236
# Saved frame 1236
# Processing frame 1238
# Saved frame 1238
# Processing frame 1240
# Saved frame 1240
# Processing frame 1242
# Saved frame 1242
# Processing frame 1244
# Saved frame 1244
# Processing frame 1246
# Saved frame 1246
# Processing frame 1248
# Saved frame 1248
# Processing frame 1250
# Saved frame 1250
# Processing frame 1252
# Saved frame 1252
# Processing frame 1254
# Saved frame 1254
# Processing frame 1256
# Saved frame 1256
# Processing frame 1258
# Saved frame 1258
# Processing frame 1260
# Saved frame 1260
# Processing frame 1262
# Saved frame 1262
# Processing frame 1264
# Saved frame 1264
# Processing frame 1266
# Saved frame 1266
# Processing frame 1268
# Saved frame 1268
# Processing frame 1270
# Saved frame 1270
# Processing frame 1272
# Saved frame 1272
# Processing frame 1274
# Saved frame 1274
# Processing frame 1276
# Saved frame 1276
# Processing frame 1278
# Saved frame 1278
# Processing frame 1280
# Saved frame 1280
# Processing frame 1282
# Saved frame 1282
# Processing frame 1284
# Saved frame 1284
# Processing frame 1286
# Saved frame 1286
# Processing frame 1288
# Saved frame 1288
# Processing frame 1290
# Saved frame 1290
# Processing frame 1292
# Saved frame 1292
# Processing frame 1294
# Saved frame 1294
# Processing frame 1296
# Saved frame 1296
# Processing frame 1298
# Saved frame 1298
# Processing frame 1300
# Saved frame 1300
# Processing frame 1302
# Saved frame 1302
# Processing frame 1304
# Saved frame 1304
# Processing frame 1306
# Saved frame 1306
# Processing frame 1308
# Saved frame 1308
# Processing frame 1310
# Saved frame 1310
# Processing frame 1312
# Saved frame 1312
# Processing frame 1314
# Saved frame 1314
# Processing frame 1316
# Saved frame 1316
# Processing frame 1318
# Saved frame 1318
# Processing frame 1320
# Saved frame 1320
# Processing frame 1322
# Saved frame 1322
# Processing frame 1324
# Saved frame 1324
# Processing frame 1326
# Saved frame 1326
# Processing frame 1328
# Saved frame 1328
# Processing frame 1330
# Saved frame 1330
# Processing frame 1332
# Saved frame 1332
# Processing frame 1334
# Saved frame 1334
# Processing frame 1336
# Saved frame 1336
# Processing frame 1338
# Saved frame 1338
# Processing frame 1340
# Saved frame 1340
# Processing frame 1342
# Saved frame 1342
# Processing frame 1344
# Saved frame 1344
# Processing frame 1346
# Saved frame 1346
# Processing frame 1348
# Saved frame 1348
# Processing frame 1350
# Saved frame 1350
# Processing frame 1352
# Saved frame 1352
# Processing frame 1354
# Saved frame 1354
# Processing frame 1356
# Saved frame 1356
# Processing frame 1358
# Saved frame 1358
# Processing frame 1360
# Saved frame 1360
# Processing frame 1362
# Saved frame 1362
# Processing frame 1364
# Saved frame 1364
# Processing frame 1366
# Saved frame 1366
# Processing frame 1368
# Saved frame 1368
# Processing frame 1370
# Saved frame 1370
# Processing frame 1372
# Saved frame 1372
# Processing frame 1374
# Saved frame 1374
# Processing frame 1376
# Saved frame 1376
# Processing frame 1378
# Saved frame 1378
# Processing frame 1380
# Saved frame 1380
# Processing frame 1382
# Saved frame 1382
# Processing frame 1384
# Saved frame 1384
# Processing frame 1386
# Saved frame 1386
# Processing frame 1388
# Saved frame 1388
# Processing frame 1390
# Saved frame 1390
# Processing frame 1392
# Saved frame 1392
# Processing frame 1394
# Saved frame 1394
# Processing frame 1396
# Saved frame 1396
# Processing frame 1398
# Saved frame 1398
# Processing frame 1400
# Saved frame 1400
# Processing frame 1402
# Saved frame 1402
# Processing frame 1404
# Saved frame 1404
# Processing frame 1406
# Saved frame 1406
# Processing frame 1408
# Saved frame 1408
# Processing frame 1410
# Saved frame 1410
# Processing frame 1412
# Saved frame 1412
# Processing frame 1414
# Saved frame 1414
# Processing frame 1416
# Saved frame 1416
# Processing frame 1418
# Saved frame 1418
# Processing frame 1420
# Saved frame 1420
# Processing frame 1422
# Saved frame 1422
# Processing frame 1424
# Saved frame 1424
# Processing frame 1426
# Saved frame 1426
# Processing frame 1428
# Saved frame 1428
# Processing frame 1430
# Saved frame 1430
# Processing frame 1432
# Saved frame 1432
# Processing frame 1434
# Saved frame 1434
# Processing frame 1436
# Saved frame 1436
# Processing frame 1438
# Saved frame 1438
# Processing frame 1440
# Saved frame 1440
# Processing frame 1442
# Saved frame 1442
# Processing frame 1444
# Saved frame 1444
# Processing frame 1446
# Saved frame 1446
# Processing frame 1448
# Saved frame 1448
# Processing frame 1450
# Saved frame 1450
# Processing frame 1452
# Saved frame 1452
# Processing frame 1454
# Saved frame 1454
# Processing frame 1456
# Saved frame 1456
# Processing frame 1458
# Saved frame 1458
# Processing frame 1460
# Saved frame 1460
# Processing frame 1462
# Saved frame 1462
# Processing frame 1464
# Saved frame 1464
# Processing frame 1466
# Saved frame 1466
# Processing frame 1468
# Saved frame 1468
# Processing frame 1470
# Saved frame 1470
# Processing frame 1472
# Saved frame 1472
# Processing frame 1474
# Saved frame 1474
# Processing frame 1476
# Saved frame 1476
# Processing frame 1478
# Saved frame 1478
# Processing frame 1480
# Saved frame 1480
# Processing frame 1482
# Saved frame 1482
# Processing frame 1484
# Saved frame 1484
# Processing frame 1486
# Saved frame 1486
# Processing frame 1488
# Saved frame 1488
# Processing frame 1490
# Saved frame 1490
# Processing frame 1492
# Saved frame 1492
# Processing frame 1494
# Saved frame 1494
# Processing frame 1496
# Saved frame 1496
# Processing frame 1498
# Saved frame 1498
# Processing frame 1500
# Saved frame 1500
# Processing frame 1502
# Saved frame 1502
# Processing frame 1504
# Saved frame 1504
# Processing frame 1506
# Saved frame 1506
# Processing frame 1508
# Saved frame 1508
# Processing frame 1510
# Saved frame 1510
# Processing frame 1512
# Saved frame 1512
# Processing frame 1514
# Saved frame 1514
# Processing frame 1516
# Saved frame 1516
# Processing frame 1518
# Saved frame 1518
# Processing frame 1520
# Saved frame 1520
# Processing frame 1522
# Saved frame 1522
# Processing frame 1524
# Saved frame 1524
# Processing frame 1526
# Saved frame 1526
# Processing frame 1528
# Saved frame 1528
# Processing frame 1530
# Saved frame 1530
# Processing frame 1532
# Saved frame 1532
# Processing frame 1534
# Saved frame 1534
# Processing frame 1536
# Saved frame 1536
# Processing frame 1538
# Saved frame 1538
# Processing frame 1540
# Saved frame 1540
# Processing frame 1542
# Saved frame 1542
# Processing frame 1544
# Saved frame 1544
# Processing frame 1546
# Saved frame 1546
# Processing frame 1548
# Saved frame 1548
# Processing frame 1550
# Saved frame 1550
# Processing frame 1552
# Saved frame 1552
# Processing frame 1554
# Saved frame 1554
# Processing frame 1556
# Saved frame 1556
# Processing frame 1558
# Saved frame 1558
# Processing frame 1560
# Saved frame 1560
# Processing frame 1562
# Saved frame 1562
# Processing frame 1564
# Saved frame 1564
# Processing frame 1566
# Saved frame 1566
# Processing frame 1568
# Saved frame 1568
# Processing frame 1570
# Saved frame 1570
# Processing frame 1572
# Saved frame 1572
# Processing frame 1574
# Saved frame 1574
# Processing frame 1576
# Saved frame 1576
# Processing frame 1578
# Saved frame 1578
# Processing frame 1580
# Saved frame 1580
# Processing frame 1582
# Saved frame 1582
# Processing frame 1584
# Saved frame 1584
# Processing frame 1586
# Saved frame 1586
# Processing frame 1588
# Saved frame 1588
# Processing frame 1590
# Saved frame 1590
# Processing frame 1592
# Saved frame 1592
# Processing frame 1594
# Saved frame 1594
# Processing frame 1596
# Saved frame 1596
# Processing frame 1598
# Saved frame 1598
# Processing frame 1600
# Saved frame 1600
# Processing frame 1602
# Saved frame 1602
# Processing frame 1604
# Saved frame 1604
# Processing frame 1606
# Saved frame 1606
# Processing frame 1608
# Saved frame 1608
# Processing frame 1610
# Saved frame 1610
# Processing frame 1612
# Saved frame 1612
# Processing frame 1614
# Saved frame 1614
# Processing frame 1616
# Saved frame 1616
# Processing frame 1618
# Saved frame 1618
# Processing frame 1620
# Saved frame 1620
# Processing frame 1622
# Saved frame 1622
# Processing frame 1624
# Saved frame 1624
# Processing frame 1626
# Saved frame 1626
# Processing frame 1628
# Saved frame 1628
# Processing frame 1630
# Saved frame 1630
# Processing frame 1632
# Saved frame 1632
# Processing frame 1634
# Saved frame 1634
# Processing frame 1636
# Saved frame 1636
# Processing frame 1638
# Saved frame 1638
# Processing frame 1640
# Saved frame 1640
# Processing frame 1642
# Saved frame 1642
# Processing frame 1644
# Saved frame 1644
# Processing frame 1646
# Saved frame 1646
# Processing frame 1648
# Saved frame 1648
# Processing frame 1650
# Saved frame 1650
# Processing frame 1652
# Saved frame 1652
# Processing frame 1654
# Saved frame 1654
# Processing frame 1656
# Saved frame 1656
# Processing frame 1658
# Saved frame 1658
# Processing frame 1660
# Saved frame 1660
# Processing frame 1662
# Saved frame 1662
# Processing frame 1664
# Saved frame 1664
# Processing frame 1666
# Saved frame 1666
# Processing frame 1668
# Saved frame 1668
# Processing frame 1670
# Saved frame 1670
# Processing frame 1672
# Saved frame 1672
# Processing frame 1674
# Saved frame 1674
# Processing frame 1676
# Saved frame 1676
# Processing frame 1678
# Saved frame 1678
# Processing frame 1680
# Saved frame 1680
# Processing frame 1682
# Saved frame 1682
# Processing frame 1684
# Saved frame 1684
# Processing frame 1686
# Saved frame 1686
# Processing frame 1688
# Saved frame 1688
# Processing frame 1690
# Saved frame 1690
# Processing frame 1692
# Saved frame 1692
# Processing frame 1694
# Saved frame 1694
# Processing frame 1696
# Saved frame 1696
# Processing frame 1698
# Saved frame 1698
# Processing frame 1700
# Saved frame 1700
# Processing frame 1702
# Saved frame 1702
# Processing frame 1704
# Saved frame 1704
# Processing frame 1706
# Saved frame 1706
# Processing frame 1708
# Saved frame 1708
# Processing frame 1710
# Saved frame 1710
# Processing frame 1712
# Saved frame 1712
# Processing frame 1714
# Saved frame 1714
# Processing frame 1716
# Saved frame 1716
# Processing frame 1718
# Saved frame 1718
# Processing frame 1720
# Saved frame 1720
# Processing frame 1722
# Saved frame 1722
# Processing frame 1724
# Saved frame 1724
# Processing frame 1726
# Saved frame 1726
# Processing frame 1728
# Saved frame 1728
# Processing frame 1730
# Saved frame 1730
# Processing frame 1732
# Saved frame 1732
# Processing frame 1734
# Saved frame 1734
# Processing frame 1736
# Saved frame 1736
# Processing frame 1738
# Saved frame 1738
# Processing frame 1740
# Saved frame 1740
# Processing frame 1742
# Saved frame 1742
# Processing frame 1744
# Saved frame 1744
# Processing frame 1746
# Saved frame 1746
# Processing frame 1748
# Saved frame 1748
# Processing frame 1750
# Saved frame 1750
# Processing frame 1752
# Saved frame 1752
# Processing frame 1754
# Saved frame 1754
# Processing frame 1756
# Saved frame 1756
# Processing frame 1758
# Saved frame 1758
# Processing frame 1760
# Saved frame 1760
# Processing frame 1762
# Saved frame 1762
# Processing frame 1764
# Saved frame 1764
# Processing frame 1766
# Saved frame 1766
# Processing frame 1768
# Saved frame 1768
# Processing frame 1770
# Saved frame 1770
# Processing frame 1772
# Saved frame 1772
# Processing frame 1774
# Saved frame 1774
# Processing frame 1776
# Saved frame 1776
# Processing frame 1778
# Saved frame 1778
# Processing frame 1780
# Saved frame 1780
# Processing frame 1782
# Saved frame 1782
# Processing frame 1784
# Saved frame 1784
# Processing frame 1786
# Saved frame 1786
# Processing frame 1788
# Saved frame 1788
# Processing frame 1790
# Saved frame 1790
# Processing frame 1792
# Saved frame 1792
# Processing frame 1794
# Saved frame 1794
# Processing frame 1796
# Saved frame 1796
# Processing frame 1798
# Saved frame 1798
# Processing frame 1800
# Saved frame 1800
# Processing frame 1802
# Saved frame 1802
# Processing frame 1804
# Saved frame 1804
# Processing frame 1806
# Saved frame 1806
# Processing frame 1808
# Saved frame 1808
# Processing frame 1810
# Saved frame 1810
# Processing frame 1812
# Saved frame 1812
# Processing frame 1814
# Saved frame 1814
# Processing frame 1816
# Saved frame 1816
# Processing frame 1818
# Saved frame 1818
# Processing frame 1820
# Saved frame 1820
# Processing frame 1822
# Saved frame 1822
# Processing frame 1824
# Saved frame 1824
# Processing frame 1826
# Saved frame 1826
# Processing frame 1828
# Saved frame 1828
# Processing frame 1830
# Saved frame 1830
# Processing frame 1832
# Saved frame 1832
# Processing frame 1834
# Saved frame 1834
# Processing frame 1836
# Saved frame 1836
# Processing frame 1838
# Saved frame 1838
# Processing frame 1840
# Saved frame 1840
# Processing frame 1842
# Saved frame 1842
# Processing frame 1844
# Saved frame 1844
# Processing frame 1846
# Saved frame 1846
# Processing frame 1848
# Saved frame 1848
# Processing frame 1850
# Saved frame 1850
# Processing frame 1852
# Saved frame 1852
# Processing frame 1854
# Saved frame 1854
# Processing frame 1856
# Saved frame 1856
# Processing frame 1858
# Saved frame 1858
# Processing frame 1860
# Saved frame 1860
# Processing frame 1862
# Saved frame 1862
# Processing frame 1864
# Saved frame 1864
# Processing frame 1866
# Saved frame 1866
# Processing frame 1868
# Saved frame 1868
# Processing frame 1870
# Saved frame 1870
# Processing frame 1872
# Saved frame 1872
# Processing frame 1874
# Saved frame 1874
# Processing frame 1876
# Saved frame 1876
# Processing frame 1878
# Saved frame 1878
# Processing frame 1880
# Saved frame 1880
# Processing frame 1882
# Saved frame 1882
# Processing frame 1884
# Saved frame 1884
# Processing frame 1886
# Saved frame 1886
# Processing frame 1888
# Saved frame 1888
# Processing frame 1890
# Saved frame 1890
# Processing frame 1892
# Saved frame 1892
# Processing frame 1894
# Saved frame 1894
# Processing frame 1896
# Saved frame 1896
# Processing frame 1898
# Saved frame 1898
# Processing frame 1900
# Saved frame 1900
# Processing frame 1902
# Saved frame 1902
# Processing frame 1904
# Saved frame 1904
# Processing frame 1906
# Saved frame 1906
# Processing frame 1908
# Saved frame 1908
# Processing frame 1910
# Saved frame 1910
# Processing frame 1912
# Saved frame 1912
# Processing frame 1914
# Saved frame 1914
# Processing frame 1916
# Saved frame 1916
# Processing frame 1918
# Saved frame 1918
# Processing frame 1920
# Saved frame 1920
# Processing frame 1922
# Saved frame 1922
# Processing frame 1924
# Saved frame 1924
# Processing frame 1926
# Saved frame 1926
# Processing frame 1928
# Saved frame 1928
# Processing frame 1930
# Saved frame 1930
# Processing frame 1932
# Saved frame 1932
# Processing frame 1934
# Saved frame 1934
# Processing frame 1936
# Saved frame 1936
# Processing frame 1938
# Saved frame 1938
# Processing frame 1940
# Saved frame 1940
# Processing frame 1942
# Saved frame 1942
# Processing frame 1944
# Saved frame 1944
# Processing frame 1946
# Saved frame 1946
# Processing frame 1948
# Saved frame 1948
# Processing frame 1950
# Saved frame 1950
# Processing frame 1952
# Saved frame 1952
# Processing frame 1954
# Saved frame 1954
# Processing frame 1956
# Saved frame 1956
# Processing frame 1958
# Saved frame 1958
# Processing frame 1960
# Saved frame 1960
# Processing frame 1962
# Saved frame 1962
# Processing frame 1964
# Saved frame 1964
# Processing frame 1966
# Saved frame 1966
# Processing frame 1968
# Saved frame 1968
# Processing frame 1970
# Saved frame 1970
# Processing frame 1972
# Saved frame 1972
# Processing frame 1974
# Saved frame 1974
# Processing frame 1976
# Saved frame 1976
# Processing frame 1978
# Saved frame 1978
# Processing frame 1980
# Saved frame 1980
# Processing frame 1982
# Saved frame 1982
# Processing frame 1984
# Saved frame 1984
# Processing frame 1986
# Saved frame 1986
# Processing frame 1988
# Saved frame 1988
# Processing frame 1990
# Saved frame 1990
# Processing frame 1992
# Saved frame 1992
# Processing frame 1994
# Saved frame 1994
# Processing frame 1996
# Saved frame 1996
# Processing frame 1998
# Saved frame 1998
# Processing frame 2000
# Saved frame 2000
# Processing frame 2002
# Saved frame 2002
# Processing frame 2004
# Saved frame 2004
# Processing frame 2006
# Saved frame 2006
# Processing frame 2008
# Saved frame 2008
# Processing frame 2010
# Saved frame 2010
# Processing frame 2012
# Saved frame 2012
# Processing frame 2014
# Saved frame 2014
# Processing frame 2016
# Saved frame 2016
# Processing frame 2018
# Saved frame 2018
# Processing frame 2020
# Saved frame 2020
# Processing frame 2022
# Saved frame 2022
# Processing frame 2024
# Saved frame 2024
# Processing frame 2026
# Saved frame 2026
# Processing frame 2028
# Saved frame 2028
# Processing frame 2030
# Saved frame 2030
# Processing frame 2032
# Saved frame 2032
# Processing frame 2034
# Saved frame 2034
# Processing frame 2036
# Saved frame 2036
# Processing frame 2038
# Saved frame 2038
# Processing frame 2040
# Saved frame 2040
# Processing frame 2042
# Saved frame 2042
# Processing frame 2044
# Saved frame 2044
# Processing frame 2046
# Saved frame 2046
# Processing frame 2048
# Saved frame 2048
# Processing frame 2050
# Saved frame 2050
# Processing frame 2052
# Saved frame 2052
# Processing frame 2054
# Saved frame 2054
# Processing frame 2056
# Saved frame 2056
# Processing frame 2058
# Saved frame 2058
# Processing frame 2060
# Saved frame 2060
# Processing frame 2062
# Saved frame 2062
# Processing frame 2064
# Saved frame 2064
# Processing frame 2066
# Saved frame 2066
# Processing frame 2068
# Saved frame 2068
# Processing frame 2070
# Saved frame 2070
# Processing frame 2072
# Saved frame 2072
# Processing frame 2074
# Saved frame 2074
# Processing frame 2076
# Saved frame 2076
# Processing frame 2078
# Saved frame 2078
# Processing frame 2080
# Saved frame 2080
# Processing frame 2082
# Saved frame 2082
# Processing frame 2084
# Saved frame 2084
# Processing frame 2086
# Saved frame 2086
# Processing frame 2088
# Saved frame 2088
# Processing frame 2090
# Saved frame 2090
# Processing frame 2092
# Saved frame 2092
# Processing frame 2094
# Saved frame 2094
# Processing frame 2096
# Saved frame 2096
# Processing frame 2098
# Saved frame 2098
# Processing frame 2100
# Saved frame 2100
# Processing frame 2102
# Saved frame 2102
# Processing frame 2104
# Saved frame 2104
# Processing frame 2106
# Saved frame 2106
# Processing frame 2108
# Saved frame 2108
# Processing frame 2110
# Saved frame 2110
# Processing frame 2112
# Saved frame 2112
# Processing frame 2114
# Saved frame 2114
# Processing frame 2116
# Saved frame 2116
# Processing frame 2118
# Saved frame 2118
# Processing frame 2120
# Saved frame 2120
# Processing frame 2122
# Saved frame 2122
# Processing frame 2124
# Saved frame 2124
# Processing frame 2126
# Saved frame 2126
# Processing frame 2128
# Saved frame 2128
# Processing frame 2130
# Saved frame 2130
# Processing frame 2132
# Saved frame 2132
# Processing frame 2134
# Saved frame 2134
# Processing frame 2136
# Saved frame 2136
# Processing frame 2138
# Saved frame 2138
# Processing frame 2140
# Saved frame 2140
# Processing frame 2142
# Saved frame 2142
# Processing frame 2144
# Saved frame 2144
# Processing frame 2146
# Saved frame 2146
# Processing frame 2148
# Saved frame 2148
# Processing frame 2150
# Saved frame 2150
# Processing frame 2152
# Saved frame 2152
# Processing frame 2154
# Saved frame 2154
# Processing frame 2156
# Saved frame 2156
# Processing frame 2158
# Saved frame 2158
# Processing frame 2160
# Saved frame 2160
# Processing frame 2162
# Saved frame 2162
# Processing frame 2164
# Saved frame 2164
# Processing frame 2166
# Saved frame 2166
# Processing frame 2168
# Saved frame 2168
# Processing frame 2170
# Saved frame 2170
# Processing frame 2172
# Saved frame 2172
# Processing frame 2174
# Saved frame 2174
# Processing frame 2176
# Saved frame 2176
# Processing frame 2178
# Saved frame 2178
# Processing frame 2180
# Saved frame 2180
# Processing frame 2182
# Saved frame 2182
# Processing frame 2184
# Saved frame 2184
# Processing frame 2186
# Saved frame 2186
# Processing frame 2188
# Saved frame 2188
# Processing frame 2190
# Saved frame 2190
# Processing frame 2192
# Saved frame 2192
# Processing frame 2194
# Saved frame 2194
# Processing frame 2196
# Saved frame 2196
# Processing frame 2198
# Saved frame 2198
# Processing frame 2200
# Saved frame 2200
# Processing frame 2202
# Saved frame 2202
# Processing frame 2204
# Saved frame 2204
# Processing frame 2206
# Saved frame 2206
# Processing frame 2208
# Saved frame 2208
# Processing frame 2210
# Saved frame 2210
# Processing frame 2212
# Saved frame 2212
# Processing frame 2214
# Saved frame 2214
# Processing frame 2216
# Saved frame 2216
# Processing frame 2218
# Saved frame 2218
# Processing frame 2220
# Saved frame 2220
# Processing frame 2222
# Saved frame 2222
# Processing frame 2224
# Saved frame 2224
# Processing frame 2226
# Saved frame 2226
# Processing frame 2228
# Saved frame 2228
# Processing frame 2230
# Saved frame 2230
# Processing frame 2232
# Saved frame 2232
# Processing frame 2234
# Saved frame 2234
# Processing frame 2236
# Saved frame 2236
# Processing frame 2238
# Saved frame 2238
# Processing frame 2240
# Saved frame 2240
# Processing frame 2242
# Saved frame 2242
# Processing frame 2244
# Saved frame 2244
# Processing frame 2246
# Saved frame 2246
# Processing frame 2248
# Saved frame 2248
# Processing frame 2250
# Saved frame 2250
# Processing frame 2252
# Saved frame 2252
# Processing frame 2254
# Saved frame 2254
# Processing frame 2256
# Saved frame 2256
# Processing frame 2258
# Saved frame 2258
# Processing frame 2260
# Saved frame 2260
# Processing frame 2262
# Saved frame 2262
# Processing frame 2264
# Saved frame 2264
# Processing frame 2266
# Saved frame 2266
# Processing frame 2268
# Saved frame 2268
# Processing frame 2270
# Saved frame 2270
# Processing frame 2272
# Saved frame 2272
# Processing frame 2274
# Saved frame 2274
# Processing frame 2276
# Saved frame 2276
# Processing frame 2278
# Saved frame 2278
# Processing frame 2280
# Saved frame 2280
# Processing frame 2282
# Saved frame 2282
# Processing frame 2284
# Saved frame 2284
# Processing frame 2286
# Saved frame 2286
# Processing frame 2288
# Saved frame 2288
# Processing frame 2290
# Saved frame 2290
# Processing frame 2292
# Saved frame 2292
# Processing frame 2294
# Saved frame 2294
# Processing frame 2296
# Saved frame 2296
# Processing frame 2298
# Saved frame 2298
# Processing frame 2300
# Saved frame 2300
# Processing frame 2302
# Saved frame 2302
# Processing frame 2304
# Saved frame 2304
# Processing frame 2306
# Saved frame 2306
# Processing frame 2308
# Saved frame 2308
# Processing frame 2310
# Saved frame 2310
# Processing frame 2312
# Saved frame 2312
# Processing frame 2314
# Saved frame 2314
# Processing frame 2316
# Saved frame 2316
# Processing frame 2318
# Saved frame 2318
# Processing frame 2320
# Saved frame 2320
# Processing frame 2322
# Saved frame 2322
# Processing frame 2324
# Saved frame 2324
# Processing frame 2326
# Saved frame 2326
# Processing frame 2328
# Saved frame 2328
# Processing frame 2330
# Saved frame 2330
# Processing frame 2332
# Saved frame 2332
# Processing frame 2334
# Saved frame 2334
# Processing frame 2336
# Saved frame 2336
# Processing frame 2338
# Saved frame 2338
# Processing frame 2340
# Saved frame 2340
# Processing frame 2342
# Saved frame 2342
# Processing frame 2344
# Saved frame 2344
# Processing frame 2346
# Saved frame 2346
# Processing frame 2348
# Saved frame 2348
# Processing frame 2350
# Saved frame 2350
# Processing frame 2352
# Saved frame 2352
# Processing frame 2354
# Saved frame 2354
# Processing frame 2356
# Saved frame 2356
# Processing frame 2358
# Saved frame 2358
# Processing frame 2360
# Saved frame 2360
# Processing frame 2362
# Saved frame 2362
# Processing frame 2364
# Saved frame 2364
# Processing frame 2366
# Saved frame 2366
# Processing frame 2368
# Saved frame 2368
# Processing frame 2370
# Saved frame 2370
# Processing frame 2372
# Saved frame 2372
# Processing frame 2374
# Saved frame 2374
# Processing frame 2376
# Saved frame 2376
# Processing frame 2378
# Saved frame 2378
# Processing frame 2380
# Saved frame 2380
# Processing frame 2382
# Saved frame 2382
# Processing frame 2384
# Saved frame 2384
# Processing frame 2386
# Saved frame 2386
# Processing frame 2388
# Saved frame 2388
# Processing frame 2390
# Saved frame 2390
# Processing frame 2392
# Saved frame 2392
# Processing frame 2394
# Saved frame 2394
# Processing frame 2396
# Saved frame 2396
# Processing frame 2398
# Saved frame 2398
# Processing frame 2400
# Saved frame 2400
# Processing frame 2402
# Saved frame 2402
# Processing frame 2404
# Saved frame 2404
# Processing frame 2406
# Saved frame 2406
# Processing frame 2408
# Saved frame 2408
# Processing frame 2410
# Saved frame 2410
# Processing frame 2412
# Saved frame 2412
# Processing frame 2414
# Saved frame 2414
# Processing frame 2416
# Saved frame 2416
# Processing frame 2418
# Saved frame 2418
# Processing frame 2420
# Saved frame 2420
# Processing frame 2422
# Saved frame 2422
# Processing frame 2424
# Saved frame 2424
# Processing frame 2426
# Saved frame 2426
# Processing frame 2428
# Saved frame 2428
# Processing frame 2430
# Saved frame 2430
# Processing frame 2432
# Saved frame 2432
# Processing frame 2434
# Saved frame 2434
# Processing frame 2436
# Saved frame 2436
# Processing frame 2438
# Saved frame 2438
# Processing frame 2440
# Saved frame 2440
# Processing frame 2442
# Saved frame 2442
# Processing frame 2444
# Saved frame 2444
# Processing frame 2446
# Saved frame 2446
# Processing frame 2448
# Saved frame 2448
# Processing frame 2450
# Saved frame 2450
# Processing frame 2452
# Saved frame 2452
# Processing frame 2454
# Saved frame 2454
# Processing frame 2456
# Saved frame 2456
# Processing frame 2458
# Saved frame 2458
# Processing frame 2460
# Saved frame 2460
# Processing frame 2462
# Saved frame 2462
# Processing frame 2464
# Saved frame 2464
# Processing frame 2466
# Saved frame 2466
# Processing frame 2468
# Saved frame 2468
# Processing frame 2470
# Saved frame 2470
# Processing frame 2472
# Saved frame 2472
# Processing frame 2474
# Saved frame 2474
# Processing frame 2476
# Saved frame 2476
# Processing frame 2478
# Saved frame 2478
# Processing frame 2480
# Saved frame 2480
# Processing frame 2482
# Saved frame 2482
# Processing frame 2484
# Saved frame 2484
# Processing frame 2486
# Saved frame 2486
# Processing frame 2488
# Saved frame 2488
# Processing frame 2490
# Saved frame 2490
# Processing frame 2492
# Saved frame 2492
# Processing frame 2494
# Saved frame 2494
# Processing frame 2496
# Saved frame 2496
# Processing frame 2498
# Saved frame 2498
# Processing frame 2500
# Saved frame 2500
# Processing frame 2502
# Saved frame 2502
# Processing frame 2504
# Saved frame 2504
# Processing frame 2506
# Saved frame 2506
# Processing frame 2508
# Saved frame 2508
# Processing frame 2510
# Saved frame 2510
# Processing frame 2512
# Saved frame 2512
# Processing frame 2514
# Saved frame 2514
# Processing frame 2516
# Saved frame 2516
# Processing frame 2518
# Saved frame 2518
# Processing frame 2520
# Saved frame 2520
# Processing frame 2522
# Saved frame 2522
# Processing frame 2524
# Saved frame 2524
# Processing frame 2526
# Saved frame 2526
# Processing frame 2528
# Saved frame 2528
# Processing frame 2530
# Saved frame 2530
# Processing frame 2532
# Saved frame 2532
# Processing frame 2534
# Saved frame 2534
# Processing frame 2536
# Saved frame 2536
# Processing frame 2538
# Saved frame 2538
# Processing frame 2540
# Saved frame 2540
# Processing frame 2542
# Saved frame 2542
# Processing frame 2544
# Saved frame 2544
# Processing frame 2546
# Saved frame 2546
# Processing frame 2548
# Saved frame 2548
# Processing frame 2550
# Saved frame 2550
# Processing frame 2552
# Saved frame 2552
# Processing frame 2554
# Saved frame 2554
# Processing frame 2556
# Saved frame 2556
# Processing frame 2558
# Saved frame 2558
# Processing frame 2560
# Saved frame 2560
# Processing frame 2562
# Saved frame 2562
# Processing frame 2564
# Saved frame 2564
# Processing frame 2566
# Saved frame 2566
# Processing frame 2568
# Saved frame 2568
# Processing frame 2570
# Saved frame 2570
# Processing frame 2572
# Saved frame 2572
# Processing frame 2574
# Saved frame 2574
# Processing frame 2576
# Saved frame 2576
# Processing frame 2578
# Saved frame 2578
# Processing frame 2580
# Saved frame 2580
# Processing frame 2582
# Saved frame 2582
# Processing frame 2584
# Saved frame 2584
# Processing frame 2586
# Saved frame 2586
# Processing frame 2588
# Saved frame 2588
# Processing frame 2590
# Saved frame 2590
# Processing frame 2592
# Saved frame 2592
# Processing frame 2594
# Saved frame 2594
# Processing frame 2596
# Saved frame 2596
# Processing frame 2598
# Saved frame 2598
# Processing frame 2600
# Saved frame 2600
# Frame extraction process completed.

# %%
#@title Functions to visualize the pose estimation results.

def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  """Draws the keypoint predictions on image.

  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.

  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %% [markdown]
# ## Preprocess the input images into CSV
#
# Because the input for our pose classifier is the *output* landmarks from the MoveNet model, we need to generate our training dataset by running labeled images through MoveNet and then capturing all the landmark data and ground truth labels into a CSV file.

# %%
#@title Functions to extract keypoints from frames and saves to csv

# Assume detect and draw_prediction_on_image functions are defined

class MoveNetPreprocessor(object):
    """Helper class to preprocess pose sample images for classification."""

    def __init__(self, images_in_folder, images_out_folder, csvs_out_path):
        """Creates a preprocessor to detection pose from images and save as CSV."""
        self._images_in_folder = images_in_folder
        self._images_out_folder = images_out_folder
        self._csvs_out_path = csvs_out_path
        self._messages = []

        # Create a temp dir to store the pose CSVs per class
        self._csvs_out_folder_per_class = tempfile.mkdtemp()

    def process(self, per_pose_class_limit=None, detection_threshold=0.1):
        """Preprocesses images in the given folder.
        Args:
          per_pose_class_limit: Number of images to load. As preprocessing usually
            takes time, this parameter can be specified to make the reduce of the
            dataset for testing.
          detection_threshold: Only keep images with all landmark confidence score
            above this threshold.
        """
        pose_class_name = "pose_class"
        print('Preprocessing', pose_class_name, file=sys.stderr)

        # Paths for the pose class.
        images_out_folder = self._images_out_folder
        csv_out_path = os.path.join(self._csvs_out_folder_per_class, pose_class_name + '.csv')
        if not os.path.exists(images_out_folder):
            os.makedirs(images_out_folder)

        # Detect landmarks in each image and write it to a CSV file
        with open(csv_out_path, 'w') as csv_out_file:
            csv_out_writer = csv.writer(csv_out_file, delimiter=',', quoting=csv.QUOTE_MINIMAL)
            # Get list of images
            image_names = sorted([n for n in os.listdir(self._images_in_folder) if not n.startswith('.')])
            if per_pose_class_limit is not None:
                image_names = image_names[:per_pose_class_limit]

            valid_image_count = 0

            # Detect pose landmarks from each image
            for image_name in tqdm.tqdm(image_names):
                image_path = os.path.join(self._images_in_folder, image_name)

                try:
                    image = tf.io.read_file(image_path)
                    image = tf.io.decode_jpeg(image)
                except:
                    self._messages.append('Skipped ' + image_path + '. Invalid image.')
                    continue
                else:
                    image = tf.io.read_file(image_path)
                    image = tf.io.decode_jpeg(image)
                    image_height, image_width, channel = image.shape

                # Skip images that isn't RGB because Movenet requires RGB images
                if channel != 3:
                    self._messages.append('Skipped ' + image_path + '. Image isn\'t in RGB format.')
                    continue
                person = detect(image)

                # Save landmarks if all landmarks were detected
                min_landmark_score = min([keypoint.score for keypoint in person.keypoints])
                should_keep_image = min_landmark_score >= detection_threshold
                if not should_keep_image:
                    self._messages.append('Skipped ' + image_path + '. No pose was confidently detected.')
                    continue

                valid_image_count += 1

                # Draw the prediction result on top of the image for debugging later
                output_overlay = draw_prediction_on_image(image.numpy().astype(np.uint8), person,
                                                          close_figure=True, keep_input_size=True)

                # Write detection result into an image file
                output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
                cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

                # Get landmarks and scale it to the same size as the input image
                pose_landmarks = np.array(
                    [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score] for keypoint in person.keypoints],
                    dtype=np.float32)

                # Write the landmark coordinates to its per-class CSV file
                coordinates = pose_landmarks.flatten().astype(str).tolist()
                csv_out_writer.writerow([image_name] + coordinates)

            if not valid_image_count:
                raise RuntimeError('No valid images found for the "{}" class.'.format(pose_class_name))

        # Print the error message collected during preprocessing.
        print('\n'.join(self._messages))

        # Combine all per-class CSVs into a single output file
        all_landmarks_df = self._all_landmarks_as_dataframe()
        all_landmarks_df.to_csv(self._csvs_out_path, index=False)

    def _all_landmarks_as_dataframe(self):
        """Merge all per-class CSVs into a single dataframe."""
        total_df = None
        csv_out_path = os.path.join(self._csvs_out_folder_per_class, 'pose_class.csv')
        per_class_df = pd.read_csv(csv_out_path, header=None)

        # Add the labels
        per_class_df['class_no'] = [0] * len(per_class_df)
        per_class_df['class_name'] = ['pose_class'] * len(per_class_df)

        # Append the folder name to the filename column (first column)
        per_class_df[per_class_df.columns[0]] = (os.path.join('pose_class', '')
            + per_class_df[per_class_df.columns[0]].astype(str))

        total_df = per_class_df

        list_name = [[bodypart.name + '_x', bodypart.name + '_y', bodypart.name + '_score'] for bodypart in BodyPart]
        header_name = []
        for columns_name in list_name:
            header_name += columns_name
        header_name = ['file_name'] + header_name
        header_map = {total_df.columns[i]: header_name[i] for i in range(len(header_name))}

        total_df.rename(header_map, axis=1, inplace=True)

        return total_df
# Example usage

images_in_folder = "exercise/woozooDance/inputFrames" #@param {type:"string"}
images_out_folder = "exercise/woozooDance/annotatedFrames" #@param {type:"string"}
csvs_out_path = "exercise/csv/woozooDance.csv"#@param {type:"string"}

preprocessor = MoveNetPreprocessor(
    images_in_folder,
    images_out_folder,
    csvs_out_path
)

preprocessor.process(per_pose_class_limit=None, detection_threshold=0.2)
# Out:
# Preprocessing pose_class
# 100%|██████████| 1301/1301 [1:12:54<00:00,  3.36s/it]
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_0.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_10.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1006.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1010.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_102.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1020.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1022.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1036.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1038.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_104.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1040.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1044.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1056.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_106.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1062.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1066.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1068.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1070.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1072.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1078.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_108.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1106.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_118.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1192.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1198.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_12.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_120.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1204.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_124.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1258.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1270.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1278.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_128.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1286.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1292.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1294.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_130.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1314.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1316.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1318.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_132.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1320.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1324.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1326.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1330.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1334.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1336.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1338.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1340.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1342.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1344.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1346.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1348.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1350.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1352.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1354.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1356.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1358.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1360.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1362.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1368.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1372.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1378.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_138.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1388.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1390.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1398.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_14.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_140.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1404.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1410.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1412.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1428.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1430.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_144.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1442.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1446.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1460.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1462.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1466.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1478.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_148.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_150.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1512.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_152.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1532.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1540.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1542.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1550.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1552.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1554.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_156.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_158.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1584.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1592.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_16.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1608.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1610.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1620.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1624.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1626.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1628.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1632.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1638.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1640.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1646.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_166.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1660.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1666.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1668.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1670.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1672.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1674.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1678.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_168.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1680.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1684.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1688.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1690.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1692.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1696.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1698.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_170.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1702.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1746.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1748.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1750.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1752.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1798.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_180.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1800.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_182.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1830.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1854.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1858.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_186.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1860.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1862.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1868.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1870.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1874.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1878.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_188.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1894.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1898.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_190.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1910.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1912.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1914.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1918.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1922.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1930.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1932.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1934.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1936.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1942.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1954.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1956.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1958.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1960.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1964.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1978.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1996.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_1998.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2002.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2008.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2010.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2012.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2014.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2020.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2024.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2026.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2028.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2038.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2040.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2044.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2046.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2050.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2054.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_206.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_208.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_210.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2118.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2132.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2134.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2138.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2140.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2150.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2154.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2156.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2158.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2160.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2162.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2164.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2170.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2172.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_218.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2184.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2186.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2192.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_22.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_220.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2204.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2216.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2218.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_222.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2220.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2224.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2226.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2228.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2230.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2236.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_224.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2240.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2246.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2256.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_226.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2260.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2270.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2272.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2274.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_228.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2282.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2286.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2290.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2292.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2294.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2300.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_232.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2348.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2352.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2366.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2372.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2374.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2376.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2378.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2380.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2382.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2384.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2386.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_240.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2436.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2480.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2516.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_252.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2520.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2538.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_254.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2556.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2560.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2564.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2566.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2568.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2570.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2572.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2574.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2576.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2580.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2582.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2584.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2586.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2588.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2590.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2592.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2594.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2596.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2598.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_2600.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_30.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_308.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_320.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_324.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_330.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_346.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_36.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_390.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_4.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_408.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_412.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_426.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_436.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_442.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_446.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_54.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_548.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_554.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_558.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_560.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_562.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_564.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_566.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_572.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_580.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_586.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_588.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_590.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_592.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_596.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_6.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_600.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_62.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_630.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_632.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_636.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_64.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_640.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_648.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_658.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_66.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_70.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_704.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_706.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_714.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_722.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_724.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_726.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_730.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_738.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_74.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_754.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_756.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_758.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_772.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_774.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_778.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_78.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_780.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_8.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_816.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_820.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_822.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_838.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_842.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_848.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_880.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_900.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_914.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_918.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_920.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_922.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_926.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_950.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_954.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_962.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_964.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_966.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_968.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_976.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_990.jpg. No pose was confidently detected.
# Skipped /content/drive/Shareddrives/Capstone C241-PS416/ML/Data/keypointsDataset/woozooDance/inputFrames/frame_992.jpg. No pose was confidently detected.
